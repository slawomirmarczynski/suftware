# %%
# Standard modules
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# Other modules
import sys
import time
import glob
import os

# Import suftware
sys.path.append('../../')
import suftware as sw

# %%
# Specify directories
raw_data_file = '../data/raw/who_data_2017.xlsx'
output_dir = '../data'

# Remove all previous WHO output files
files_to_remove = glob.glob('%s/who.*.txt'%output_dir)
for file in files_to_remove:
    os.remove(file)

# %%
# Load raw data
df = pd.read_excel(raw_data_file, header=None, skiprows=4)
df.head(10)
# Out:
#             0                 1                        2   \
# 0  Description  Total population  Life expectancy, \nmale
# 1        Units         thousands                    years
# 2      Dataset        population     life_expectancy_male
# 3        Years              2015                     2015
# 4          NaN               NaN                      NaN
# 5  Afghanistan             32527                     59.3
# 6      Albania              2897                     75.1
# 7      Algeria             39667                     73.8
# 8      Andorra                70                      NaN
# 9       Angola             25022                     50.9
#
#                           3                4                         5   \
# 0  Life expectancy, \nfemale  Life expectancy  Healthy life expectancy
# 1                      years            years                     years
# 2     life_expectancy_female  life_expectancy   life_expectancy_healthy
# 3                       2015             2015                      2015
# 4                        NaN              NaN                       NaN
# 5                       61.9             60.5                      52.2
# 6                       80.7             77.8                      68.8
# 7                       77.5             75.6                      66.0
# 8                        NaN              NaN                       NaN
# 9                       54.0             52.4                      45.8
#
#                         6                7                      8   \
# 0       Maternal mortality  Attended births   Under-five mortality
# 1  per 100,000 live births          percent  per 1,000 live births
# 2       maternal_mortality  attended_births   under_five_mortality
# 3                     2015        2005–2016                   2015
# 4                      NaN              NaN                    NaN
# 5                      396               51                   91.1
# 6                       29               99                   14.0
# 7                      140               97                   25.5
# 8                      NaN              NaN                    2.8
# 9                      477               47                  156.9
#
#                       9           ...                            32  \
# 0     Neonatal moraltiy           ...           Wasting in children
# 1  per 1,000 live births          ...                       percent
# 2     neonatal_moratlity          ...                 child_wasting
# 3                   2015          ...                     2005-2016
# 4                    NaN          ...                           NaN
# 5                   35.5          ...                           9.5
# 6                    6.2          ...                           9.4
# 7                   15.5          ...                           4.1
# 8                    1.4          ...                           NaN
# 9                   48.7          ...                           4.9
#
#                     33                     34                     35  \
# 0  Overweight children            Clean water             Sanitation
# 1              percent  percent of population  percent of population
# 2     child_overweight            clean_water             sanitation
# 3            2005-2016                   2015                   2015
# 4                  NaN                    NaN                    NaN
# 5                  5.4                     55                     32
# 6                 23.4                     95                     93
# 7                 12.4                     84                     88
# 8                  NaN                    100                    100
# 9                  3.3                     49                     52
#
#                       36                         37  \
# 0            Clean fuels  Particulate matter in air
# 1  percent of population  micrograms per cubi meter
# 2            clean_fuels         particulate_matter
# 3                   2014                       2014
# 4                    NaN                        NaN
# 5                     17                       63.4
# 6                     67                       17.1
# 7                     95                       25.1
# 8                     95                       10.5
# 9                     48                       42.4
#
#                                 38                  39  \
# 0  Annual natural diaster \ndeaths  Homicide mortality
# 1                      per 100,000         per 100,000
# 2                natural_disasters            homicide
# 3                        2011-2015                2015
# 4                              NaN                 NaN
# 5                              0.8                 7.0
# 6                              0.0                 4.1
# 7                              0.1                 4.2
# 8                              NaN                 NaN
# 9                              0.1                 9.6
#
#                               40                    41
# 0  Deaths from major \nconflicts  Cause of death known
# 1                    per 100,000               percent
# 2                conflict_deaths  cause_of_death_known
# 3                      2011-2015             2005-2015
# 4                            NaN                   NaN
# 5                           40.9                   NaN
# 6                            0.1                    76
# 7                            1.0                   NaN
# 8                            NaN                   100
# 9                            0.0                   NaN
#
# [10 rows x 42 columns]

# %%
descriptions = df.iloc[0,1:].values
units = df.iloc[1,1:].values
names = df.iloc[2,1:].values
years = df.iloc[3,1:].values
num_datasets = df.shape[1]-1

for i in range(num_datasets):
    
    # Extract data values
    values = df.iloc[5:,i+1].values.astype(float)
    description_str = repr(descriptions[i] + ' (%s)'%years[i])
    
    # Format file contentx
    header = '# "description": %s\n# "name": "%s"\n# "units": "%s"\n'%\
                (description_str, names[i], units[i])
    contents = ''.join(['%.1f\n'%x for x in values])
    
    # Write file
    file_name = '%s/who.%s.txt'%(output_dir,names[i])
    print('Writing %s'%file_name)
    with open(file_name,'w') as f:
        f.write(header)
        f.write(contents)
# Out:
# Writing ../data/who.population.txt
# Writing ../data/who.life_expectancy_male.txt
# Writing ../data/who.life_expectancy_female.txt
# Writing ../data/who.life_expectancy.txt
# Writing ../data/who.life_expectancy_healthy.txt
# Writing ../data/who.maternal_mortality.txt
# Writing ../data/who.attended_births.txt
# Writing ../data/who.under_five_mortality.txt
# Writing ../data/who.neonatal_moratlity.txt
# Writing ../data/who.hiv_infections.txt
# Writing ../data/who.tb_indicence.txt
# Writing ../data/who.malaria_incidence.txt
# Writing ../data/who.hepatitis_vaccine.txt
# Writing ../data/who.ntd_interventions.txt
# Writing ../data/who.early_disease_deaths.txt
# Writing ../data/who.suicide_moratlity.txt
# Writing ../data/who.alcohol_consumption.txt
# Writing ../data/who.traffic_mortality.txt
# Writing ../data/who.family_planning.txt
# Writing ../data/who.adolescent_births.txt
# Writing ../data/who.air_pollution_mortality.txt
# Writing ../data/who.wash_mortality.txt
# Writing ../data/who.poisoning_mortality.txt
# Writing ../data/who.smoking_male.txt
# Writing ../data/who.smoking_female.txt
# Writing ../data/who.dpt_immunization.txt
# Writing ../data/who.health_and_research.txt
# Writing ../data/who.health_professionals.txt
# Writing ../data/who.score_avg.txt
# Writing ../data/who.govt_expendature.txt
# Writing ../data/who.child_stunting.txt
# Writing ../data/who.child_wasting.txt
# Writing ../data/who.child_overweight.txt
# Writing ../data/who.clean_water.txt
# Writing ../data/who.sanitation.txt
# Writing ../data/who.clean_fuels.txt
# Writing ../data/who.particulate_matter.txt
# Writing ../data/who.natural_disasters.txt
# Writing ../data/who.homicide.txt
# Writing ../data/who.conflict_deaths.txt
# Writing ../data/who.cause_of_death_known.txt

# %%
! head ../data/who.life_expectancy_male.txt
# Out:
# # "description": 'Life expectancy, \nmale (2015)'
# # "name": "life_expectancy_male"
# # "units": "years"
# 59.3
# 75.1
# 73.8
# nan
# 50.9
# 74.1
# 72.7

# %%
repr(descriptions[i])
# Out:
# "'Cause of death known'"

# %%
descriptions[i]
# Out:
# 'Cause of death known'
