# %%
# Standard modules
import numpy as np
import matplotlib.pyplot as plt
import sys

# Import suftware 
sys.path.append('../../')
import suftware as sw

### Load example data ###
data, details = sw.example_density_data('who.hepatitis_vaccine')

### Perform density estimation using DEFT 1D ###
density = sw.Density(data)  

### Plot results ###
density.plot(title=details['description'], xlabel=details['units'])
