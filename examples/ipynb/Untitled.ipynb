# %%
import numpy as np
import sys
sys.path.append('../../')
import suftware as sw

# Generate random data
data = np.random.randn(100)

# Perform one-dimensional density estimation using SUFTware
density = sw.Density(data)

# Visualize results
density.plot()

# %%
import os
os.getcwd()
# Out:
# '/Users/jkinney/github/deft_1d/examples/ipynb'
