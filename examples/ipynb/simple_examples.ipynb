# %%
# Standard modules
import numpy as np
import sys

# Import suftware 
sys.path.append('../../')
import suftware as sw
sw.enable_graphics()
# %matplotlib inline

# %%
### On custom synthetic data ###

# Generate datas
data = np.random.randn(100)

# Perform density estimation
density = sw.Density(data)  

# Plot results
density.plot(title='Gaussian')

# %%
### On SUFTware-generated data ##

# Generate data
data = sw.simulate_density_data('wide', N=30)

# Perform density estimation
density = sw.Density(data)  

# Plot results
density.plot(title='Gaussian mixture')

# %%
### On example data ###

# Load data
data, details = sw.example_density_data('who.alcohol_consumption')

# Perform density estimation
density = sw.Density(data)  

# Plot results
density.plot(title=details['description'], xlabel=details['units'])
